# %% [markdown]
# ## 加载训练集数据

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
content = pd.read_csv('D:/Machine Learning/NLP/data/titanic/train.csv')
content = content.dropna()
age_with_fares = content[(content['Age']>22)&(content['Fare']<400)&(content['Fare']>130)]
sub_fare = age_with_fares['Fare']
sub_age = age_with_fares['Age']

# %%
sub_fare
# Out:
# 88     263.0000
# 118    247.5208
# 195    146.5208
# 268    153.4625
# 269    135.6333
# 299    247.5208
# 318    164.8667
# 319    134.5000
# 325    135.6333
# 332    153.4625
# 337    134.5000
# 341    263.0000
# 377    211.5000
# 438    263.0000
# 498    151.5500
# 609    153.4625
# 716    227.5250
# 730    211.3375
# 779    211.3375
# Name: Fare, dtype: float64

# %%
sub_age
# Out:
# 88     23.0
# 118    24.0
# 195    58.0
# 268    58.0
# 269    35.0
# 299    50.0
# 318    31.0
# 319    40.0
# 325    36.0
# 332    38.0
# 337    41.0
# 341    24.0
# 377    27.0
# 438    64.0
# 498    25.0
# 609    40.0
# 716    38.0
# 730    29.0
# 779    43.0
# Name: Age, dtype: float64

# %% [markdown]
# ## 机器学习模型定义

# %%
def func(age, k, b):
    return k * age + b

# %% [markdown]
# ## 损失函数定义

# %%
def loss(y, yhat):
    return np.mean(np.abs(y-yhat))

# %% [markdown]
# ## 1. Random Choose Method to get optimal k and b

# %% [markdown]
# ### 超参数定义

# %%
loop_times = 10000

# %% [markdown]
# ### 模型训练

# %%
best_k, best_b = None, None
min_error_rate = float('inf')

losses = []

while loop_times > 0:

    k_hat, b_hat = random.random() * 20 - 10, random.random() * 20 - 10
    estimated_fares = func(sub_age, k_hat, b_hat)
    error_rate = loss(sub_fare, estimated_fares)

    if error_rate < min_error_rate:
        min_error_rate = error_rate
        best_k, best_b = k_hat, b_hat
        print('after {} loops, the current loss is {}'.format(10000-loop_times, error_rate))
        losses.append(error_rate)
    loop_times -= 1


# 画图观察loss的收敛过程
plt.title('convergence process of losses')
plt.xlabel('time')
plt.ylabel('loss')
plt.plot(range(len(losses)), losses)
plt.show()
# Out:
# after 0 loops, the current loss is 447.800527833723
# after 1 loops, the current loss is 189.6974320684902
# after 3 loops, the current loss is 116.72250427486216
# after 5 loops, the current loss is 91.71261352113291
# after 6 loops, the current loss is 78.88058969526078
# after 9 loops, the current loss is 61.26480480293088
# after 1103 loops, the current loss is 61.23288316920328
# after 3940 loops, the current loss is 61.214005217762086
# after 5385 loops, the current loss is 61.15817549848727
# after 7204 loops, the current loss is 61.00980846084051

# %% [markdown]
# ## 2. Supervised Direction to get optimal k and b

# %%
loop_times = 10000

change_directions = [(-1,-1),(-1,1),(1,-1),(1,1)]
direction = random.choice(change_directions)

def step():
    return random.random() * 1

new_k, new_b = random.random() * 20 - 10, random.random() * 20 - 10
best_k, best_b = random.random() * 20 - 10, random.random() * 20 - 10

min_error_rate = float('inf')
losses = []

while loop_times > 0:

    k_delta_direction, b_delta_direction = direction
    k_delta, b_delta = k_delta_direction * step(), b_delta_direction * step()    # optimizer
#     new_k, new_b = new_k + k_delta, new_b + b_delta
    new_k, new_b = best_k + k_delta, best_b + b_delta

    estimated_fares = func(sub_age, new_k, new_b)
    error_rate = loss(sub_fare, estimated_fares)    # 计算loss

    if error_rate < min_error_rate:
        min_error_rate = error_rate
        best_k, best_b = new_k, new_b
        print('after {} loops, the current loss is {}'.format(10000-loop_times, error_rate))
        losses.append(error_rate)
    else:
        direction = random.choice(list(set(change_directions) - {(k_delta_direction, b_delta_direction)}))
    

    loop_times -= 1


# 画图观察loss的收敛过程
plt.title('convergence process of losses')
plt.xlabel('time')
plt.ylabel('loss')
plt.plot(range(len(losses)), losses)
plt.show()
# Out:
# after 0 loops, the current loss is 192.7430500652394
# after 3 loops, the current loss is 176.71431933926286
# after 4 loops, the current loss is 157.12504843988017
# after 5 loops, the current loss is 138.24058808311008
# after 6 loops, the current loss is 126.76704285813786
# after 7 loops, the current loss is 111.06791625338847
# after 8 loops, the current loss is 107.54592156914201
# after 9 loops, the current loss is 87.80728561320291
# after 10 loops, the current loss is 80.98240888237513
# after 11 loops, the current loss is 77.59468054732312
# after 12 loops, the current loss is 65.49724030229318
# after 13 loops, the current loss is 65.41909843289808
# after 14 loops, the current loss is 61.8312416906329
# after 18 loops, the current loss is 61.81492889480436
# after 21 loops, the current loss is 61.677183719916286
# after 69 loops, the current loss is 61.656078875474456
# after 88 loops, the current loss is 61.59753856902933
# after 94 loops, the current loss is 61.563076177742005
# after 104 loops, the current loss is 61.41680781155037
# after 176 loops, the current loss is 61.389269068688535
# after 206 loops, the current loss is 61.31286034860407
# after 279 loops, the current loss is 61.307540265691124
# after 385 loops, the current loss is 61.28471953802703
# after 398 loops, the current loss is 61.15782273984751
# after 416 loops, the current loss is 61.130241638287224
# after 438 loops, the current loss is 61.00210486760837
# after 491 loops, the current loss is 60.98269631529821
# after 496 loops, the current loss is 60.964952742162126
# after 540 loops, the current loss is 60.891809331191276
# after 543 loops, the current loss is 60.82593232958575
# after 556 loops, the current loss is 60.77891273897549
# after 632 loops, the current loss is 60.683035728530704
# after 639 loops, the current loss is 60.62324180672856
# after 683 loops, the current loss is 60.46560125077328
# after 693 loops, the current loss is 60.455984642582436
# after 714 loops, the current loss is 60.449186710112734
# after 767 loops, the current loss is 60.41400594665407
# after 869 loops, the current loss is 60.362620412751454
# after 870 loops, the current loss is 60.280433030313446
# after 874 loops, the current loss is 60.2177223908298
# after 998 loops, the current loss is 60.14179253707803
# after 1090 loops, the current loss is 60.122813967468524
# after 1103 loops, the current loss is 60.12009467078427
# after 1143 loops, the current loss is 59.97784663915644
# after 1155 loops, the current loss is 59.949170698245574
# after 1159 loops, the current loss is 59.84396980712509
# after 1182 loops, the current loss is 59.744649174273405
# after 1185 loops, the current loss is 59.74060778921886
# after 1209 loops, the current loss is 59.70452674462873
# after 1211 loops, the current loss is 59.66177926442454
# after 1259 loops, the current loss is 59.64030329574713
# after 1312 loops, the current loss is 59.523129053979346
# after 1322 loops, the current loss is 59.450410789835274
# after 1337 loops, the current loss is 59.4121294915929
# after 1340 loops, the current loss is 59.32254379301008
# after 1345 loops, the current loss is 59.26560328028137
# after 1364 loops, the current loss is 59.23085034901216
# after 1366 loops, the current loss is 59.11299785128627
# after 1428 loops, the current loss is 59.10095197553822
# after 1463 loops, the current loss is 59.087900066633836
# after 1498 loops, the current loss is 58.927646396603016
# after 1551 loops, the current loss is 58.854229455304534
# after 1568 loops, the current loss is 58.8179215199697
# after 1578 loops, the current loss is 58.796344784588825
# after 1592 loops, the current loss is 58.777057460711795
# after 1645 loops, the current loss is 58.76329598007608
# after 1768 loops, the current loss is 58.7018068120538
# after 1774 loops, the current loss is 58.591256946587166
# after 1799 loops, the current loss is 58.572636181244455
# after 1802 loops, the current loss is 58.50337893181932
# after 1816 loops, the current loss is 58.37932043654039
# after 1852 loops, the current loss is 58.33287390902756
# after 1858 loops, the current loss is 58.315154748261506
# after 1890 loops, the current loss is 58.17971936383396
# after 1963 loops, the current loss is 58.09542850905524
# after 2005 loops, the current loss is 58.08656565158064
# after 2044 loops, the current loss is 58.020155356302475
# after 2077 loops, the current loss is 57.88645516535736
# after 2110 loops, the current loss is 57.87062307042692
# after 2130 loops, the current loss is 57.758415558014526
# after 2202 loops, the current loss is 57.74608177080743
# after 2220 loops, the current loss is 57.666620364338804
# after 2223 loops, the current loss is 57.651983913938935
# after 2238 loops, the current loss is 57.57152507893663
# after 2240 loops, the current loss is 57.540033212831936
# after 2334 loops, the current loss is 57.50205552812446
# after 2382 loops, the current loss is 57.43622820718472
# after 2400 loops, the current loss is 57.38210815775674
# after 2427 loops, the current loss is 57.23151204905992
# after 2439 loops, the current loss is 57.228654967743346
# after 2472 loops, the current loss is 57.15705008941558
# after 2534 loops, the current loss is 57.08756428406227
# after 2536 loops, the current loss is 56.95864771869292
# after 2545 loops, the current loss is 56.85194586938944
# after 2552 loops, the current loss is 56.79104070580491
# after 2562 loops, the current loss is 56.711092114305984
# after 2688 loops, the current loss is 56.56911892849946
# after 2889 loops, the current loss is 56.53263354429677
# after 2894 loops, the current loss is 56.45745395377328
# after 2953 loops, the current loss is 56.396166263267425
# after 2968 loops, the current loss is 56.303751098435725
# after 3001 loops, the current loss is 56.152426357344034
# after 3005 loops, the current loss is 56.029863270219806
# after 3029 loops, the current loss is 55.965455663085265
# after 3035 loops, the current loss is 55.92017712571235
# after 3055 loops, the current loss is 55.91658054075763
# after 3187 loops, the current loss is 55.844181957385324
# after 3190 loops, the current loss is 55.8330002501838
# after 3275 loops, the current loss is 55.78582970786776
# after 3305 loops, the current loss is 55.74082733016558
# after 3415 loops, the current loss is 55.731866338567045
# after 3440 loops, the current loss is 55.62087937110494
# after 3520 loops, the current loss is 55.58365564338424
# after 3555 loops, the current loss is 55.565250852746935
# after 3599 loops, the current loss is 55.51839488395257
# after 3705 loops, the current loss is 55.47070301681973
# after 3733 loops, the current loss is 55.31745234441624
# after 3755 loops, the current loss is 55.3017102428052
# after 3829 loops, the current loss is 55.25097829606832
# after 3830 loops, the current loss is 55.15736983434073
# after 3856 loops, the current loss is 55.14927039654975
# after 3870 loops, the current loss is 55.07150697770857
# after 3879 loops, the current loss is 55.006049036401656
# after 3894 loops, the current loss is 54.95541987372218
# after 3897 loops, the current loss is 54.91762384251246
# after 3930 loops, the current loss is 54.827234153731524
# after 4098 loops, the current loss is 54.773526682303924
# after 4216 loops, the current loss is 54.623602119822166
# after 4219 loops, the current loss is 54.59491057913733
# after 4240 loops, the current loss is 54.55200963183025
# after 4242 loops, the current loss is 54.5154003573092
# after 4273 loops, the current loss is 54.42790616489943
# after 4281 loops, the current loss is 54.28530295990637
# after 4303 loops, the current loss is 54.156301004928274
# after 4372 loops, the current loss is 54.098138612136346
# after 4416 loops, the current loss is 54.01203489776449
# after 4437 loops, the current loss is 54.0037373637658
# after 4473 loops, the current loss is 53.90883989536293
# after 4495 loops, the current loss is 53.896336341622735
# after 4498 loops, the current loss is 53.661685522841374
# after 4863 loops, the current loss is 53.558848095655776
# after 4873 loops, the current loss is 53.5344489998208
# after 4937 loops, the current loss is 53.41788735590552
# after 4941 loops, the current loss is 53.40677769000768
# after 4982 loops, the current loss is 53.362386360373286
# after 5002 loops, the current loss is 53.359527078621596
# after 5008 loops, the current loss is 53.32174824321232
# after 5013 loops, the current loss is 53.18120136955826
# after 5047 loops, the current loss is 53.130477134663295
# after 5102 loops, the current loss is 53.097328190668044
# after 5157 loops, the current loss is 53.05769710551933
# after 5169 loops, the current loss is 52.97552248790597
# after 5190 loops, the current loss is 52.851679259985055
# after 5246 loops, the current loss is 52.81825093605007
# after 5249 loops, the current loss is 52.803010653053136
# after 5256 loops, the current loss is 52.746377040376295
# after 5318 loops, the current loss is 52.681515313320475
# after 5357 loops, the current loss is 52.65039805017919
# after 5583 loops, the current loss is 52.56941651032594
# after 5629 loops, the current loss is 52.53835902893898
# after 5632 loops, the current loss is 52.466314582688454
# after 5648 loops, the current loss is 52.400725864020416
# after 5662 loops, the current loss is 52.37170354482009
# after 5691 loops, the current loss is 52.2948677980454
# after 5703 loops, the current loss is 52.26592647309759
# after 5755 loops, the current loss is 52.20584877076252
# after 5782 loops, the current loss is 52.13719551754854
# after 5784 loops, the current loss is 51.99763982419167
# after 5823 loops, the current loss is 51.91926471438313
# after 5891 loops, the current loss is 51.898557313722
# after 5908 loops, the current loss is 51.82876708393376
# after 5941 loops, the current loss is 51.76570954446925
# after 5952 loops, the current loss is 51.73086124234876
# after 5964 loops, the current loss is 51.69867645525409
# after 5978 loops, the current loss is 51.69286259729845
# after 5984 loops, the current loss is 51.670594430510825
# after 5988 loops, the current loss is 51.58716508024139
# after 5990 loops, the current loss is 51.57498736052213
# after 6008 loops, the current loss is 51.48437427218904
# after 6013 loops, the current loss is 51.421497368548216
# after 6043 loops, the current loss is 51.30040198149505
# after 6104 loops, the current loss is 51.23845168493133
# after 6105 loops, the current loss is 51.16954505408895
# after 6124 loops, the current loss is 51.10054186429799
# after 6155 loops, the current loss is 51.081580056814495
# after 6174 loops, the current loss is 51.05757488255296
# after 6177 loops, the current loss is 51.02061601998116
# after 6196 loops, the current loss is 50.94600106946721
# after 6209 loops, the current loss is 50.92722983759169
# after 6219 loops, the current loss is 50.86433688445566
# after 6460 loops, the current loss is 50.818040248226346
# after 6535 loops, the current loss is 50.75783742577398
# after 6599 loops, the current loss is 50.74192008537407
# after 6605 loops, the current loss is 50.66834286334028
# after 6615 loops, the current loss is 50.58408831062407
# after 6625 loops, the current loss is 50.57561170492552
# after 6630 loops, the current loss is 50.55639285732295
# after 6652 loops, the current loss is 50.465785333867586
# after 6773 loops, the current loss is 50.3941816153309
# after 6809 loops, the current loss is 50.30309566484859
# after 6883 loops, the current loss is 50.25948332230861
# after 6977 loops, the current loss is 50.25163608043617
# after 7004 loops, the current loss is 50.19579067306106
# after 7008 loops, the current loss is 50.153729455211305
# after 7147 loops, the current loss is 50.07840258560503
# after 7268 loops, the current loss is 50.07016049087299
# after 7280 loops, the current loss is 50.06578221684106
# after 7341 loops, the current loss is 50.06501800932267
# after 7349 loops, the current loss is 50.03695987764777
# after 7380 loops, the current loss is 49.986611622250514
# after 7473 loops, the current loss is 49.979950312269814
# after 7497 loops, the current loss is 49.95318937770551
# after 7506 loops, the current loss is 49.93861581750206
# after 7541 loops, the current loss is 49.87056866336066
# after 7586 loops, the current loss is 49.86680010717299
# after 7597 loops, the current loss is 49.82748502062719
# after 7614 loops, the current loss is 49.773808174736786
# after 7625 loops, the current loss is 49.66366385195935
# after 7770 loops, the current loss is 49.65264917062938
# after 7777 loops, the current loss is 49.64775756570491
# after 7790 loops, the current loss is 49.543931834214234
# after 7848 loops, the current loss is 49.47799532305371
# after 7851 loops, the current loss is 49.44251471657958
# after 7854 loops, the current loss is 49.416843122871306
# after 7856 loops, the current loss is 49.332611500997615
# after 7857 loops, the current loss is 49.32412446057522
# after 7876 loops, the current loss is 49.24697102669929
# after 7915 loops, the current loss is 49.202277630380806
# after 7932 loops, the current loss is 49.10320024704265
# after 7967 loops, the current loss is 49.100752554831985
# after 7975 loops, the current loss is 49.03820554262402
# after 8030 loops, the current loss is 49.03100497301514
# after 8037 loops, the current loss is 48.85366521766199
# after 8039 loops, the current loss is 48.80531894386587
# after 8071 loops, the current loss is 48.76675489920552
# after 8090 loops, the current loss is 48.76627446130573
# after 8103 loops, the current loss is 48.664563884399236
# after 8124 loops, the current loss is 48.63958268678465
# after 8136 loops, the current loss is 48.58032097003236
# after 8145 loops, the current loss is 48.572808375006794
# after 8161 loops, the current loss is 48.56455529018124
# after 8197 loops, the current loss is 48.53136655142586
# after 8202 loops, the current loss is 48.51760665564688
# after 8221 loops, the current loss is 48.393721807817485
# after 8321 loops, the current loss is 48.34165269173345
# after 8403 loops, the current loss is 48.269088009225605
# after 8407 loops, the current loss is 48.201789675889124
# after 8408 loops, the current loss is 48.16403928325891
# after 8414 loops, the current loss is 48.1114726808511
# after 8417 loops, the current loss is 48.10733523280557
# after 8420 loops, the current loss is 48.03815551332591
# after 8422 loops, the current loss is 47.98066961883425
# after 8443 loops, the current loss is 47.96264954835016
# after 8448 loops, the current loss is 47.91549200859044
# after 8473 loops, the current loss is 47.84208777762298
# after 8510 loops, the current loss is 47.825722158812816
# after 8529 loops, the current loss is 47.7757929901222
# after 8571 loops, the current loss is 47.755275050231624
# after 8572 loops, the current loss is 47.6965385780138
# after 8576 loops, the current loss is 47.6463630112726
# after 8593 loops, the current loss is 47.596775003838594
# after 8597 loops, the current loss is 47.59347363329759
# after 8621 loops, the current loss is 47.51406173181543
# after 8641 loops, the current loss is 47.48378423692028
# after 8642 loops, the current loss is 47.4355608605497
# after 8682 loops, the current loss is 47.37932319970085
# after 8693 loops, the current loss is 47.32654301298279
# after 8698 loops, the current loss is 47.32331158039864
# after 8703 loops, the current loss is 47.26261631973752
# after 8729 loops, the current loss is 47.12344726259871
# after 8769 loops, the current loss is 47.08087144222264
# after 8789 loops, the current loss is 47.07858879461576
# after 8811 loops, the current loss is 47.02897208911756
# after 8889 loops, the current loss is 46.98113124687086
# after 8984 loops, the current loss is 46.98084787641551
# after 9009 loops, the current loss is 46.88965566493073
# after 9100 loops, the current loss is 46.82124028562747
# after 9161 loops, the current loss is 46.81048608299254
# after 9192 loops, the current loss is 46.800801517892005
# after 9217 loops, the current loss is 46.74036627893829
# after 9237 loops, the current loss is 46.65109177982561
# after 9261 loops, the current loss is 46.63795411572655
# after 9268 loops, the current loss is 46.46425434657379
# after 9279 loops, the current loss is 46.45607940549419
# after 9297 loops, the current loss is 46.380663323251895
# after 9321 loops, the current loss is 46.28326732815812
# after 9335 loops, the current loss is 46.14945917665765
# after 9336 loops, the current loss is 46.14665818618158
# after 9340 loops, the current loss is 46.00958142030535
# after 9351 loops, the current loss is 45.9805591696552
# after 9363 loops, the current loss is 45.92927667743893
# after 9416 loops, the current loss is 45.855328740269066
# after 9534 loops, the current loss is 45.80168500215819
# after 9552 loops, the current loss is 45.79354638786605
# after 9621 loops, the current loss is 45.769722285230365
# after 9630 loops, the current loss is 45.71416718772906
# after 9657 loops, the current loss is 45.69274581156266
# after 9731 loops, the current loss is 45.66955157639206
# after 9750 loops, the current loss is 45.612033888792
# after 9785 loops, the current loss is 45.53899316992942
# after 9790 loops, the current loss is 45.52837957025982
# after 9810 loops, the current loss is 45.46804257509691
# after 9944 loops, the current loss is 45.4540389325706

# %% [markdown]
# ## 3. Gradient Descent to get optimal k and b

# %%
loop_times = 10000

def derivate(y, yhat, x):
    abs_values = [1 if (y_i - yhat_i) > 0 else -1 for y_i, yhat_i in zip(y, yhat)]
    return np.mean([a * -x_i for a, x_i in zip(abs_values, x)])
def derivate_b(y, yhat):
    abs_values = [1 if (y_i - yhat_i) > 0 else -1 for y_i, yhat_i in zip(y, yhat)]
    return np.mean([a * -1 for a in abs_values])

learning_rate = 1e-1

k_hat, b_hat = random.random() * 20 - 10, random.random() * 20 - 10
losses = []
min_error_rate = float('inf')

while loop_times > 0:

    k_delta, b_delta = -1 * learning_rate * derivate(sub_fare, func(sub_age,k_hat,b_hat),sub_age), -1 * learning_rate * derivate_b(sub_fare, func(sub_age, k_hat, b_hat))
    k_hat, b_hat = k_hat + k_delta, b_hat + b_delta

    estimated_fares = func(sub_age, k_hat, b_hat)
    error_rate = loss(sub_fare, estimated_fares)

    if error_rate < min_error_rate:
        min_error_rate = error_rate
        best_k, best_b = k_hat, b_hat
        print('after {} loops, the current loss is {}'.format(10000-loop_times, error_rate))
        losses.append(error_rate)

    loop_times -= 1

    
# 画图观察loss的收敛过程
plt.title('convergence process of losses')
plt.xlabel('time')
plt.ylabel('loss')
plt.plot(range(len(losses)), losses)
plt.show()
# Out:
# after 0 loops, the current loss is 70.40649106329352
# after 1 loops, the current loss is 64.98079608423372
# after 9 loops, the current loss is 64.38213464515191
# after 25 loops, the current loss is 64.1095584678666
# after 49 loops, the current loss is 64.05803492216029
# after 73 loops, the current loss is 64.00651137645394
# after 97 loops, the current loss is 63.954987830747626
# after 121 loops, the current loss is 63.903464285041295
# after 145 loops, the current loss is 63.85194073933497
# after 169 loops, the current loss is 63.80041719362864
# after 193 loops, the current loss is 63.7488936479223
# after 217 loops, the current loss is 63.69737010221596
# after 241 loops, the current loss is 63.645846556509646
# after 265 loops, the current loss is 63.59432301080331
# after 393 loops, the current loss is 63.55775791385063
# after 417 loops, the current loss is 63.506234368144305
# after 441 loops, the current loss is 63.45471082243797
# after 483 loops, the current loss is 63.401525226870206
# after 579 loops, the current loss is 63.34335348171806
# after 1099 loops, the current loss is 63.115976139638526
# after 1325 loops, the current loss is 62.209835476179876
# after 1327 loops, the current loss is 59.51066668781246
# after 1328 loops, the current loss is 59.22451710332495
# after 1334 loops, the current loss is 59.17049608857794
# after 1359 loops, the current loss is 59.15138251517073
# after 1384 loops, the current loss is 59.13226894176355
# after 1400 loops, the current loss is 59.01370938497688
# after 1425 loops, the current loss is 58.99459581156967
# after 1450 loops, the current loss is 58.97548223816247
# after 1466 loops, the current loss is 58.87327056592877
# after 1470 loops, the current loss is 58.86496031662131
# after 1474 loops, the current loss is 58.856650067313815
# after 1478 loops, the current loss is 58.848612432068286
# after 1503 loops, the current loss is 58.82949885866111
# after 1519 loops, the current loss is 58.789891064543696
# after 1523 loops, the current loss is 58.78158081523623
# after 1527 loops, the current loss is 58.77327056592874
# after 1531 loops, the current loss is 58.76496031662126
# after 1535 loops, the current loss is 58.7566500673138
# after 1539 loops, the current loss is 58.74833981800629
# after 1543 loops, the current loss is 58.74002956869883
# after 1547 loops, the current loss is 58.73171931939135
# after 1551 loops, the current loss is 58.723409070083875
# after 1555 loops, the current loss is 58.7150988207764
# after 1559 loops, the current loss is 58.706788571468906
# after 1563 loops, the current loss is 58.69847832216144
# after 1567 loops, the current loss is 58.690168072853936
# after 1571 loops, the current loss is 58.68185782354647
# after 1575 loops, the current loss is 58.67354757423898
# after 1579 loops, the current loss is 58.669388055337
# after 1595 loops, the current loss is 58.6641292916905
# after 1599 loops, the current loss is 58.65581904238302
# after 1603 loops, the current loss is 58.64750879307555
# after 1607 loops, the current loss is 58.639198543768075
# after 1611 loops, the current loss is 58.630888294460576
# after 1615 loops, the current loss is 58.6225780451531
# after 1619 loops, the current loss is 58.61426779584563
# after 1623 loops, the current loss is 58.60595754653815
# after 1627 loops, the current loss is 58.59764729723067
# after 1631 loops, the current loss is 58.58933704792317
# after 1635 loops, the current loss is 58.581026798615696
# after 1639 loops, the current loss is 58.572716549308254
# after 1643 loops, the current loss is 58.56440630000074
# after 1647 loops, the current loss is 58.55609605069326
# after 1651 loops, the current loss is 58.547785801385785
# after 1655 loops, the current loss is 58.53947555207831
# after 1659 loops, the current loss is 58.53116530277085
# after 1663 loops, the current loss is 58.52285505346334
# after 1667 loops, the current loss is 58.51454480415586
# after 1671 loops, the current loss is 58.50623455484839
# after 1675 loops, the current loss is 58.49792430554091
# after 1679 loops, the current loss is 58.492656753397966
# after 1714 loops, the current loss is 58.48656696482067
# after 1718 loops, the current loss is 58.478256715513204
# after 1722 loops, the current loss is 58.46994646620571
# after 1726 loops, the current loss is 58.461636216898235
# after 1730 loops, the current loss is 58.45332596759076
# after 1734 loops, the current loss is 58.445015718283265
# after 1738 loops, the current loss is 58.4367054689758
# after 1742 loops, the current loss is 58.428395219668325
# after 1746 loops, the current loss is 58.42008497036083
# after 1750 loops, the current loss is 58.411774721053355
# after 1754 loops, the current loss is 58.403464471745885
# after 1758 loops, the current loss is 58.3951542224384
# after 1762 loops, the current loss is 58.38684397313093
# after 1766 loops, the current loss is 58.37853372382343
# after 1770 loops, the current loss is 58.37022347451597
# after 1774 loops, the current loss is 58.36191322520849
# after 1778 loops, the current loss is 58.353602975901
# after 1782 loops, the current loss is 58.34529272659353
# after 1786 loops, the current loss is 58.33698247728603
# after 1790 loops, the current loss is 58.328672227978565
# after 1794 loops, the current loss is 58.32036197867109
# after 1798 loops, the current loss is 58.312051729363596
# after 1802 loops, the current loss is 58.303741480056104
# after 1806 loops, the current loss is 58.29543123074864
# after 1810 loops, the current loss is 58.28712098144116
# after 1814 loops, the current loss is 58.27881073213367
# after 1818 loops, the current loss is 58.27050048282619
# after 1822 loops, the current loss is 58.2621902335187
# after 1826 loops, the current loss is 58.25387998421124
# after 1830 loops, the current loss is 58.24556973490376
# after 1834 loops, the current loss is 58.23725948559629
# after 1838 loops, the current loss is 58.22894923628879
# after 1842 loops, the current loss is 58.220638986981314
# after 1846 loops, the current loss is 58.21232873767385
# after 1850 loops, the current loss is 58.20401848836636
# after 1854 loops, the current loss is 58.19570823905889
# after 1858 loops, the current loss is 58.18739798975139
# after 1862 loops, the current loss is 58.179087740443926
# after 1866 loops, the current loss is 58.170777491136434
# after 1870 loops, the current loss is 58.162467241828956
# after 1874 loops, the current loss is 58.154156992521486
# after 1878 loops, the current loss is 58.14584674321399
# after 1882 loops, the current loss is 58.13891714120959
# after 1917 loops, the current loss is 58.13448940249378
# after 1921 loops, the current loss is 58.1261791531863
# after 1925 loops, the current loss is 58.11786890387881
# after 1929 loops, the current loss is 58.109558654571316
# after 1933 loops, the current loss is 58.10124840526387
# after 1937 loops, the current loss is 58.092938155956375
# after 1941 loops, the current loss is 58.08462790664888
# after 1945 loops, the current loss is 58.076317657341406
# after 1949 loops, the current loss is 58.06800740803394
# after 1953 loops, the current loss is 58.05969715872645
# after 1957 loops, the current loss is 58.05138690941897
# after 1961 loops, the current loss is 58.0430766601115
# after 1965 loops, the current loss is 58.03476641080402
# after 1969 loops, the current loss is 58.02645616149654
# after 1973 loops, the current loss is 58.01814591218907
# after 1977 loops, the current loss is 58.00983566288159
# after 1981 loops, the current loss is 58.00152541357411
# after 1985 loops, the current loss is 57.99321516426665
# after 1989 loops, the current loss is 57.984904914959145
# after 1993 loops, the current loss is 57.97659466565167
# after 1997 loops, the current loss is 57.96828441634422
# after 2001 loops, the current loss is 57.95997416703671
# after 2005 loops, the current loss is 57.951663917729235
# after 2009 loops, the current loss is 57.94335366842177
# after 2013 loops, the current loss is 57.935043419114265
# after 2017 loops, the current loss is 57.92673316980679
# after 2021 loops, the current loss is 57.918422920499324
# after 2025 loops, the current loss is 57.91011267119185
# after 2029 loops, the current loss is 57.901802421884355
# after 2033 loops, the current loss is 57.89349217257689
# after 2037 loops, the current loss is 57.88518192326942
# after 2041 loops, the current loss is 57.87687167396192
# after 2045 loops, the current loss is 57.86856142465446
# after 2049 loops, the current loss is 57.86025117534699
# after 2053 loops, the current loss is 57.851940926039504
# after 2057 loops, the current loss is 57.84363067673201
# after 2061 loops, the current loss is 57.835320427424556
# after 2065 loops, the current loss is 57.827010178117064
# after 2069 loops, the current loss is 57.81869992880958
# after 2073 loops, the current loss is 57.8103896795021
# after 2077 loops, the current loss is 57.80207943019463
# after 2081 loops, the current loss is 57.793769180887146
# after 2085 loops, the current loss is 57.78545893157966
# after 2089 loops, the current loss is 57.782407445918736
# after 2124 loops, the current loss is 57.774101590859466
# after 2128 loops, the current loss is 57.765791341551974
# after 2132 loops, the current loss is 57.7574810922445
# after 2136 loops, the current loss is 57.74917084293703
# after 2140 loops, the current loss is 57.74086059362954
# after 2144 loops, the current loss is 57.73255034432208
# after 2148 loops, the current loss is 57.72424009501461
# after 2152 loops, the current loss is 57.71592984570711
# after 2156 loops, the current loss is 57.70761959639964
# after 2160 loops, the current loss is 57.699309347092154
# after 2164 loops, the current loss is 57.690999097784676
# after 2168 loops, the current loss is 57.682688848477206
# after 2172 loops, the current loss is 57.67437859916972
# after 2176 loops, the current loss is 57.666068349862236
# after 2180 loops, the current loss is 57.65775810055477
# after 2184 loops, the current loss is 57.64944785124728
# after 2188 loops, the current loss is 57.6411376019398
# after 2192 loops, the current loss is 57.632827352632326
# after 2196 loops, the current loss is 57.62451710332485
# after 2200 loops, the current loss is 57.616206854017356
# after 2204 loops, the current loss is 57.60789660470989
# after 2208 loops, the current loss is 57.599586355402415
# after 2212 loops, the current loss is 57.59127610609494
# after 2216 loops, the current loss is 57.58296585678746
# after 2220 loops, the current loss is 57.57465560747998
# after 2224 loops, the current loss is 57.56634535817252
# after 2228 loops, the current loss is 57.55803510886503
# after 2232 loops, the current loss is 57.54972485955755
# after 2236 loops, the current loss is 57.54141461025008
# after 2240 loops, the current loss is 57.533104360942595
# after 2244 loops, the current loss is 57.5247941116351
# after 2248 loops, the current loss is 57.51648386232765
# after 2252 loops, the current loss is 57.508173613020155
# after 2256 loops, the current loss is 57.49986336371267
# after 2260 loops, the current loss is 57.49155311440519
# after 2264 loops, the current loss is 57.48324286509772
# after 2268 loops, the current loss is 57.47493261579024
# after 2272 loops, the current loss is 57.46662236648277
# after 2276 loops, the current loss is 57.4583121171753
# after 2280 loops, the current loss is 57.4500018678678
# after 2284 loops, the current loss is 57.441691618560334
# after 2288 loops, the current loss is 57.43338136925286
# after 2292 loops, the current loss is 57.42866783373038
# after 2377 loops, the current loss is 57.425348128255635
# after 2381 loops, the current loss is 57.41703787894814
# after 2385 loops, the current loss is 57.408727629640666
# after 2389 loops, the current loss is 57.40041738033319
# after 2393 loops, the current loss is 57.39210713102571
# after 2397 loops, the current loss is 57.38379688171823
# after 2401 loops, the current loss is 57.37548663241078
# after 2405 loops, the current loss is 57.36717638310328
# after 2409 loops, the current loss is 57.358866133795814
# after 2413 loops, the current loss is 57.350555884488344
# after 2417 loops, the current loss is 57.342245635180845
# after 2421 loops, the current loss is 57.33393538587338
# after 2425 loops, the current loss is 57.32562513656589
# after 2429 loops, the current loss is 57.31731488725841
# after 2433 loops, the current loss is 57.30900463795094
# after 2437 loops, the current loss is 57.30069438864346
# after 2441 loops, the current loss is 57.29238413933598
# after 2445 loops, the current loss is 57.2840738900285
# after 2449 loops, the current loss is 57.27576364072102
# after 2453 loops, the current loss is 57.267453391413554
# after 2457 loops, the current loss is 57.25914314210606
# after 2461 loops, the current loss is 57.250832892798584
# after 2465 loops, the current loss is 57.24252264349112
# after 2469 loops, the current loss is 57.23421239418363
# after 2473 loops, the current loss is 57.22590214487615
# after 2477 loops, the current loss is 57.21759189556869
# after 2481 loops, the current loss is 57.209281646261196
# after 2485 loops, the current loss is 57.20097139695372
# after 2489 loops, the current loss is 57.19266114764624
# after 2493 loops, the current loss is 57.184350898338764
# after 2497 loops, the current loss is 57.17604064903127
# after 2501 loops, the current loss is 57.167730399723794
# after 2505 loops, the current loss is 57.15942015041633
# after 2509 loops, the current loss is 57.15110990110884
# after 2513 loops, the current loss is 57.14279965180136
# after 2517 loops, the current loss is 57.1344894024939
# after 2521 loops, the current loss is 57.126179153186406
# after 2525 loops, the current loss is 57.11786890387893
# after 2529 loops, the current loss is 57.10955865457146
# after 2533 loops, the current loss is 57.10124840526397
# after 2537 loops, the current loss is 57.0929381559565
# after 2541 loops, the current loss is 57.084627906649025
# after 2545 loops, the current loss is 57.07631765734154
# after 2549 loops, the current loss is 57.06800740803407
# after 2553 loops, the current loss is 57.05969715872658
# after 2557 loops, the current loss is 57.0513869094191
# after 2561 loops, the current loss is 57.04307666011164
# after 2565 loops, the current loss is 57.034766410804146
# after 2569 loops, the current loss is 57.02645616149667
# after 2573 loops, the current loss is 57.01814591218919
# after 2577 loops, the current loss is 57.00983566288171
# after 2581 loops, the current loss is 57.00152541357425
# after 2585 loops, the current loss is 56.99321516426676
# after 2589 loops, the current loss is 56.98490491495928
# after 2593 loops, the current loss is 56.97659466565182
# after 2597 loops, the current loss is 56.968284416344325
# after 2601 loops, the current loss is 56.95997416703685
# after 2605 loops, the current loss is 56.95166391772938
# after 2609 loops, the current loss is 56.94335366842189
# after 2613 loops, the current loss is 56.935043419114415
# after 2617 loops, the current loss is 56.92673316980694
# after 2621 loops, the current loss is 56.91842292049946
# after 2625 loops, the current loss is 56.91011267119197
# after 2629 loops, the current loss is 56.90180242188449
# after 2633 loops, the current loss is 56.89349217257702
# after 2637 loops, the current loss is 56.885181923269535
# after 2641 loops, the current loss is 56.87687167396206
# after 2645 loops, the current loss is 56.86856142465458
# after 2649 loops, the current loss is 56.860251175347095
# after 2653 loops, the current loss is 56.85194092603962
# after 2657 loops, the current loss is 56.84363067673217
# after 2661 loops, the current loss is 56.83532042742466
# after 2665 loops, the current loss is 56.8270101781172
# after 2669 loops, the current loss is 56.818699928809735
# after 2673 loops, the current loss is 56.81038967950223
# after 2677 loops, the current loss is 56.802079430194766
# after 2681 loops, the current loss is 56.793769180887274
# after 2685 loops, the current loss is 56.7854589315798
# after 2689 loops, the current loss is 56.77714868227233
# after 2693 loops, the current loss is 56.76883843296484
# after 2697 loops, the current loss is 56.760528183657364
# after 2701 loops, the current loss is 56.752217934349886
# after 2705 loops, the current loss is 56.74390768504241
# after 2709 loops, the current loss is 56.73559743573494
# after 2713 loops, the current loss is 56.72728718642745
# after 2717 loops, the current loss is 56.718976937119976
# after 2721 loops, the current loss is 56.710666687812505
# after 2725 loops, the current loss is 56.702356438505014
# after 2729 loops, the current loss is 56.694046189197536
# after 2733 loops, the current loss is 56.68573593989007
# after 2737 loops, the current loss is 56.67742569058258
# after 2741 loops, the current loss is 56.6691154412751
# after 2745 loops, the current loss is 56.660805191967626
# after 2749 loops, the current loss is 56.65249494266015
# after 2753 loops, the current loss is 56.644184693352656
# after 2757 loops, the current loss is 56.63587444404518
# after 2761 loops, the current loss is 56.627564194737715
# after 2765 loops, the current loss is 56.61925394543022
# after 2769 loops, the current loss is 56.610943696122746
# after 2773 loops, the current loss is 56.60263344681528
# after 2777 loops, the current loss is 56.59432319750779
# after 2781 loops, the current loss is 56.58601294820031
# after 2785 loops, the current loss is 56.57770269889285
# after 2789 loops, the current loss is 56.56939244958536
# after 2793 loops, the current loss is 56.561082200277895
# after 2797 loops, the current loss is 56.55277195097042
# after 2801 loops, the current loss is 56.544461701662925
# after 2805 loops, the current loss is 56.5414102160019
# after 2809 loops, the current loss is 56.53864013289941
# after 2813 loops, the current loss is 56.53587004979692
# after 2817 loops, the current loss is 56.53309996669442
# after 2821 loops, the current loss is 56.53032988359193
# after 2825 loops, the current loss is 56.52755980048944
# after 2829 loops, the current loss is 56.524789717386945
# after 2833 loops, the current loss is 56.52201963428444
# after 2837 loops, the current loss is 56.519249551181964
# after 2841 loops, the current loss is 56.51647946807947
# after 2845 loops, the current loss is 56.51370938497696
# after 2849 loops, the current loss is 56.51093930187449
# after 2853 loops, the current loss is 56.508169218771975
# after 2857 loops, the current loss is 56.50539913566947
# after 2861 loops, the current loss is 56.502629052566995
# after 2865 loops, the current loss is 56.4998589694645
# after 2869 loops, the current loss is 56.49708888636201
# after 2873 loops, the current loss is 56.49431880325952
# after 2877 loops, the current loss is 56.49154872015702
# after 2881 loops, the current loss is 56.48877863705453
# after 2885 loops, the current loss is 56.486008553952026
# after 2889 loops, the current loss is 56.48323847084955
# after 2893 loops, the current loss is 56.48046838774704
# after 2897 loops, the current loss is 56.47769830464455
# after 2901 loops, the current loss is 56.47492822154207
# after 2905 loops, the current loss is 56.47215813843959
# after 2909 loops, the current loss is 56.46938805533707
# after 2913 loops, the current loss is 56.466617972234594
# after 2917 loops, the current loss is 56.463847889132104
# after 2921 loops, the current loss is 56.46107780602961
# after 2925 loops, the current loss is 56.45830772292711
# after 2929 loops, the current loss is 56.45553763982463
# after 2933 loops, the current loss is 56.452767556722144
# after 2937 loops, the current loss is 56.44999747361964
# after 2941 loops, the current loss is 56.44722739051715
# after 2945 loops, the current loss is 56.44445730741465
# after 2949 loops, the current loss is 56.44168722431216
# after 2953 loops, the current loss is 56.43891714120967
# after 2957 loops, the current loss is 56.436147058107174
# after 2961 loops, the current loss is 56.43337697500467
# after 2965 loops, the current loss is 56.430606891902194
# after 2969 loops, the current loss is 56.4278368087997
# after 2973 loops, the current loss is 56.42506672569719
# after 2977 loops, the current loss is 56.422296642594716
# after 2981 loops, the current loss is 56.41952655949222
# after 2985 loops, the current loss is 56.41675647638971
# after 2989 loops, the current loss is 56.413986393287225
# after 2993 loops, the current loss is 56.41121631018474
# after 2997 loops, the current loss is 56.40844622708224
# after 3001 loops, the current loss is 56.40567614397975
# after 3005 loops, the current loss is 56.402906060877264
# after 3008 loops, the current loss is 56.398478322161594
# after 3012 loops, the current loss is 56.3901680728541
# after 3016 loops, the current loss is 56.381857823546625
# after 3020 loops, the current loss is 56.37354757423916
# after 3024 loops, the current loss is 56.365237324931684
# after 3028 loops, the current loss is 56.356927075624206
# after 3032 loops, the current loss is 56.34861682631672
# after 3036 loops, the current loss is 56.340306577009244
# after 3040 loops, the current loss is 56.331996327701766
# after 3044 loops, the current loss is 56.32368607839429
# after 3048 loops, the current loss is 56.31537582908681
# after 3052 loops, the current loss is 56.307065579779334
# after 3056 loops, the current loss is 56.298755330471856
# after 3060 loops, the current loss is 56.290445081164364
# after 3064 loops, the current loss is 56.28213483185689
# after 3068 loops, the current loss is 56.2738245825494
# after 3072 loops, the current loss is 56.265514333241946
# after 3076 loops, the current loss is 56.257204083934454
# after 3080 loops, the current loss is 56.24889383462696
# after 3084 loops, the current loss is 56.24058358531951
# after 3088 loops, the current loss is 56.232273336012035
# after 3092 loops, the current loss is 56.22396308670454
# after 3096 loops, the current loss is 56.215652837397066
# after 3100 loops, the current loss is 56.2073425880896
# after 3104 loops, the current loss is 56.19903233878211
# after 3108 loops, the current loss is 56.19072208947463
# after 3112 loops, the current loss is 56.18241184016716
# after 3116 loops, the current loss is 56.17410159085968
# after 3120 loops, the current loss is 56.1657913415522
# after 3124 loops, the current loss is 56.15748109224473
# after 3128 loops, the current loss is 56.14917084293723
# after 3132 loops, the current loss is 56.14086059362975
# after 3136 loops, the current loss is 56.13255034432228
# after 3140 loops, the current loss is 56.1242400950148
# after 3144 loops, the current loss is 56.11592984570732
# after 3148 loops, the current loss is 56.10761959639985
# after 3152 loops, the current loss is 56.09930934709237
# after 3156 loops, the current loss is 56.090999097784895
# after 3160 loops, the current loss is 56.08268884847742
# after 3164 loops, the current loss is 56.07437859916994
# after 3168 loops, the current loss is 56.06606834986246
# after 3172 loops, the current loss is 56.05775810055497
# after 3176 loops, the current loss is 56.04944785124751
# after 3180 loops, the current loss is 56.04113760194003
# after 3184 loops, the current loss is 56.03282735263254
# after 3188 loops, the current loss is 56.02451710332506
# after 3192 loops, the current loss is 56.01620685401758
# after 3196 loops, the current loss is 56.007896604710105
# after 3200 loops, the current loss is 55.99958635540264
# after 3204 loops, the current loss is 55.99127610609515
# after 3208 loops, the current loss is 55.98296585678766
# after 3212 loops, the current loss is 55.9746556074802
# after 3216 loops, the current loss is 55.966345358172724
# after 3220 loops, the current loss is 55.95803510886524
# after 3224 loops, the current loss is 55.94972485955776
# after 3228 loops, the current loss is 55.94141461025029
# after 3232 loops, the current loss is 55.9331043609428
# after 3236 loops, the current loss is 55.92479411163532
# after 3240 loops, the current loss is 55.91648386232786
# after 3244 loops, the current loss is 55.90817361302037
# after 3248 loops, the current loss is 55.89986336371289
# after 3252 loops, the current loss is 55.891553114405426
# after 3256 loops, the current loss is 55.88324286509792
# after 3260 loops, the current loss is 55.87493261579044
# after 3264 loops, the current loss is 55.86662236648298
# after 3268 loops, the current loss is 55.85831211717549
# after 3272 loops, the current loss is 55.85000186786801
# after 3276 loops, the current loss is 55.841691618560546
# after 3280 loops, the current loss is 55.83338136925307
# after 3284 loops, the current loss is 55.82507111994559
# after 3288 loops, the current loss is 55.81676087063811
# after 3292 loops, the current loss is 55.808450621330635
# after 3296 loops, the current loss is 55.80014037202316
# after 3300 loops, the current loss is 55.79183012271568
# after 3304 loops, the current loss is 55.7835198734082
# after 3308 loops, the current loss is 55.77520962410072
# after 3312 loops, the current loss is 55.76689937479324
# after 3316 loops, the current loss is 55.758589125485756
# after 3320 loops, the current loss is 55.75027887617828
# after 3324 loops, the current loss is 55.741968626870786
# after 3328 loops, the current loss is 55.73365837756333
# after 3332 loops, the current loss is 55.72534812825584
# after 3336 loops, the current loss is 55.717037878948354
# after 3340 loops, the current loss is 55.70872762964088
# after 3344 loops, the current loss is 55.70041738033342
# after 3348 loops, the current loss is 55.69210713102593
# after 3352 loops, the current loss is 55.68379688171845
# after 3356 loops, the current loss is 55.67548663241099
# after 3360 loops, the current loss is 55.667176383103495
# after 3364 loops, the current loss is 55.65886613379602
# after 3368 loops, the current loss is 55.650555884488554
# after 3372 loops, the current loss is 55.64224563518106
# after 3376 loops, the current loss is 55.633935385873585
# after 3380 loops, the current loss is 55.62562513656612
# after 3384 loops, the current loss is 55.617314887258615
# after 3388 loops, the current loss is 55.60900463795114
# after 3392 loops, the current loss is 55.600694388643674
# after 3396 loops, the current loss is 55.5923841393362
# after 3400 loops, the current loss is 55.584073890028705
# after 3404 loops, the current loss is 55.57576364072124
# after 3408 loops, the current loss is 55.56745339141376
# after 3412 loops, the current loss is 55.55914314210628
# after 3416 loops, the current loss is 55.5508328927988
# after 3420 loops, the current loss is 55.542522643491324
# after 3424 loops, the current loss is 55.53421239418385
# after 3428 loops, the current loss is 55.52590214487636
# after 3432 loops, the current loss is 55.51759189556889
# after 3436 loops, the current loss is 55.509281646261414
# after 3440 loops, the current loss is 55.50097139695392
# after 3444 loops, the current loss is 55.492661147646444
# after 3448 loops, the current loss is 55.48435089833897
# after 3452 loops, the current loss is 55.47604064903149
# after 3456 loops, the current loss is 55.46773039972401
# after 3460 loops, the current loss is 55.45942015041655
# after 3464 loops, the current loss is 55.45110990110904
# after 3468 loops, the current loss is 55.44279965180158
# after 3472 loops, the current loss is 55.434489402494115
# after 3476 loops, the current loss is 55.426179153186624
# after 3480 loops, the current loss is 55.417868903879146
# after 3484 loops, the current loss is 55.409558654571676
# after 3488 loops, the current loss is 55.40124840526419
# after 3492 loops, the current loss is 55.39293815595671
# after 3496 loops, the current loss is 55.38462790664924
# after 3500 loops, the current loss is 55.37631765734176
# after 3504 loops, the current loss is 55.36800740803428
# after 3508 loops, the current loss is 55.35969715872681
# after 3512 loops, the current loss is 55.35138690941931
# after 3516 loops, the current loss is 55.343076660111834
# after 3520 loops, the current loss is 55.33476641080436
# after 3524 loops, the current loss is 55.326456161496885
# after 3528 loops, the current loss is 55.3181459121894
# after 3532 loops, the current loss is 55.30983566288193
# after 3536 loops, the current loss is 55.30152541357445
# after 3540 loops, the current loss is 55.293215164266975
# after 3544 loops, the current loss is 55.2849049149595
# after 3548 loops, the current loss is 55.27659466565202
# after 3552 loops, the current loss is 55.26828441634454
# after 3556 loops, the current loss is 55.259974167037065
# after 3560 loops, the current loss is 55.25166391772959
# after 3564 loops, the current loss is 55.24335366842211
# after 3568 loops, the current loss is 55.23504341911463
# after 3572 loops, the current loss is 55.22673316980714
# after 3576 loops, the current loss is 55.21842292049966
# after 3580 loops, the current loss is 55.21011267119217
# after 3584 loops, the current loss is 55.20180242188471
# after 3588 loops, the current loss is 55.19349217257724
# after 3592 loops, the current loss is 55.18518192326974
# after 3596 loops, the current loss is 55.176871673962275
# after 3600 loops, the current loss is 55.168561424654804
# after 3604 loops, the current loss is 55.16025117534732
# after 3608 loops, the current loss is 55.151940926039835
# after 3612 loops, the current loss is 55.14363067673237
# after 3616 loops, the current loss is 55.13532042742488
# after 3620 loops, the current loss is 55.1270101781174
# after 3624 loops, the current loss is 55.12340467583576
# after 3628 loops, the current loss is 55.12063459273327
# after 3632 loops, the current loss is 55.11786450963077
# after 3636 loops, the current loss is 55.11509442652828
# after 3640 loops, the current loss is 55.112324343425776
# after 3644 loops, the current loss is 55.109554260323286
# after 3648 loops, the current loss is 55.1067841772208
# after 3652 loops, the current loss is 55.1040140941183
# after 3656 loops, the current loss is 55.10124401101582
# after 3660 loops, the current loss is 55.098473927913325
# after 3664 loops, the current loss is 55.095703844810835
# after 3668 loops, the current loss is 55.092933761708345
# after 3672 loops, the current loss is 55.09016367860583
# after 3676 loops, the current loss is 55.08739359550336
# after 3680 loops, the current loss is 55.08462351240087
# after 3684 loops, the current loss is 55.081853429298356
# after 3688 loops, the current loss is 55.07908334619588
# after 3692 loops, the current loss is 55.07631326309339
# after 3696 loops, the current loss is 55.07354317999088
# after 3700 loops, the current loss is 55.07077309688839
# after 3704 loops, the current loss is 55.06800301378589
# after 3708 loops, the current loss is 55.0652329306834
# after 3712 loops, the current loss is 55.06246284758091
# after 3716 loops, the current loss is 55.05969276447842
# after 3720 loops, the current loss is 55.05692268137593
# after 3724 loops, the current loss is 55.05415259827343
# after 3728 loops, the current loss is 55.05138251517094
# after 3732 loops, the current loss is 55.04861243206845
# after 3736 loops, the current loss is 55.045842348965955
# after 3740 loops, the current loss is 55.043072265863465
# after 3744 loops, the current loss is 55.040302182760975
# after 3748 loops, the current loss is 55.03753209965848
# after 3752 loops, the current loss is 55.034762016556
# after 3756 loops, the current loss is 55.0319919334535
# after 3760 loops, the current loss is 55.029221850351
# after 3764 loops, the current loss is 55.026451767248496
# after 3768 loops, the current loss is 55.023681684146005
# after 3772 loops, the current loss is 55.02091160104352
# after 3776 loops, the current loss is 55.01814151794102
# after 3780 loops, the current loss is 55.01537143483853
# after 3784 loops, the current loss is 55.01260135173605
# after 3788 loops, the current loss is 55.00983126863354
# after 3792 loops, the current loss is 55.007061185531064
# after 3796 loops, the current loss is 55.004291102428574
# after 3800 loops, the current loss is 55.00152101932606
# after 3804 loops, the current loss is 54.99875093622359
# after 3808 loops, the current loss is 54.9959808531211
# after 3812 loops, the current loss is 54.993210770018585
# after 3816 loops, the current loss is 54.99044068691611
# after 3820 loops, the current loss is 54.98767060381362
# after 3824 loops, the current loss is 54.98490052071111
# after 3827 loops, the current loss is 54.98102679861607
# after 3831 loops, the current loss is 54.972716549308586
# after 3835 loops, the current loss is 54.964406300001095
# after 3839 loops, the current loss is 54.95609605069364
# after 3843 loops, the current loss is 54.947785801386146
# after 3847 loops, the current loss is 54.93947555207866
# after 3851 loops, the current loss is 54.931165302771205
# after 3855 loops, the current loss is 54.92285505346373
# after 3859 loops, the current loss is 54.91454480415623
# after 3863 loops, the current loss is 54.90623455484876
# after 3867 loops, the current loss is 54.897924305541295
# after 3871 loops, the current loss is 54.88961405623379
# after 3875 loops, the current loss is 54.881303806926326
# after 3879 loops, the current loss is 54.87299355761885
# after 3883 loops, the current loss is 54.86468330831137
# after 3887 loops, the current loss is 54.85637305900389
# after 3891 loops, the current loss is 54.84806280969642
# after 3895 loops, the current loss is 54.83975256038894
# after 3899 loops, the current loss is 54.831442311081446
# after 3903 loops, the current loss is 54.82313206177399
# after 3907 loops, the current loss is 54.814821812466505
# after 3911 loops, the current loss is 54.80651156315901
# after 3915 loops, the current loss is 54.79820131385156
# after 3919 loops, the current loss is 54.789891064544065
# after 3923 loops, the current loss is 54.78158081523658
# after 3927 loops, the current loss is 54.77327056592911
# after 3931 loops, the current loss is 54.76496031662163
# after 3935 loops, the current loss is 54.75665006731415
# after 3939 loops, the current loss is 54.74833981800666
# after 3943 loops, the current loss is 54.740029568699185
# after 3947 loops, the current loss is 54.73171931939171
# after 3951 loops, the current loss is 54.72340907008422
# after 3955 loops, the current loss is 54.71509882077678
# after 3959 loops, the current loss is 54.706788571469275
# after 3963 loops, the current loss is 54.69847832216178
# after 3967 loops, the current loss is 54.69016807285432
# after 3971 loops, the current loss is 54.68185782354684
# after 3975 loops, the current loss is 54.67354757423935
# after 3979 loops, the current loss is 54.66523732493189
# after 3983 loops, the current loss is 54.656927075624424
# after 3987 loops, the current loss is 54.64861682631692
# after 3991 loops, the current loss is 54.640306577009454
# after 3995 loops, the current loss is 54.631996327701984
# after 3999 loops, the current loss is 54.623686078394485
# after 4003 loops, the current loss is 54.61537582908702
# after 4007 loops, the current loss is 54.607065579779544
# after 4011 loops, the current loss is 54.598755330472066
# after 4015 loops, the current loss is 54.59044508116458
# after 4019 loops, the current loss is 54.58213483185712
# after 4023 loops, the current loss is 54.573824582549626
# after 4027 loops, the current loss is 54.56551433324214
# after 4031 loops, the current loss is 54.557204083934685
# after 4035 loops, the current loss is 54.548893834627194
# after 4039 loops, the current loss is 54.5405835853197
# after 4043 loops, the current loss is 54.53227333601225
# after 4047 loops, the current loss is 54.52396308670476
# after 4051 loops, the current loss is 54.51565283739727
# after 4055 loops, the current loss is 54.507342588089806
# after 4059 loops, the current loss is 54.49903233878233
# after 4063 loops, the current loss is 54.490722089474836
# after 4067 loops, the current loss is 54.48241184016736
# after 4071 loops, the current loss is 54.47410159085988
# after 4075 loops, the current loss is 54.4657913415524
# after 4079 loops, the current loss is 54.45748109224491
# after 4083 loops, the current loss is 54.44917084293746
# after 4087 loops, the current loss is 54.44086059362997
# after 4091 loops, the current loss is 54.43255034432248
# after 4095 loops, the current loss is 54.42424009501502
# after 4099 loops, the current loss is 54.41592984570754
# after 4103 loops, the current loss is 54.407619596400046
# after 4107 loops, the current loss is 54.39930934709259
# after 4111 loops, the current loss is 54.39099909778511
# after 4115 loops, the current loss is 54.38268884847761
# after 4119 loops, the current loss is 54.37437859917014
# after 4123 loops, the current loss is 54.36606834986268
# after 4127 loops, the current loss is 54.35775810055518
# after 4131 loops, the current loss is 54.34944785124771
# after 4135 loops, the current loss is 54.34113760194023
# after 4139 loops, the current loss is 54.332827352632755
# after 4143 loops, the current loss is 54.32451710332528
# after 4147 loops, the current loss is 54.316206854017814
# after 4151 loops, the current loss is 54.30789660471032
# after 4155 loops, the current loss is 54.29958635540283
# after 4159 loops, the current loss is 54.29127610609538
# after 4163 loops, the current loss is 54.28296585678789
# after 4167 loops, the current loss is 54.2746556074804
# after 4171 loops, the current loss is 54.26634535817294
# after 4175 loops, the current loss is 54.25803510886546
# after 4179 loops, the current loss is 54.249724859557965
# after 4183 loops, the current loss is 54.2414146102505
# after 4187 loops, the current loss is 54.233104360943024
# after 4191 loops, the current loss is 54.22479411163553
# after 4195 loops, the current loss is 54.216483862328054
# after 4199 loops, the current loss is 54.20817361302058
# after 4203 loops, the current loss is 54.1998633637131
# after 4207 loops, the current loss is 54.19155311440561
# after 4211 loops, the current loss is 54.183242865098165
# after 4215 loops, the current loss is 54.17493261579066
# after 4219 loops, the current loss is 54.166622366483175
# after 4223 loops, the current loss is 54.158312117175704
# after 4227 loops, the current loss is 54.15000186786823
# after 4231 loops, the current loss is 54.14169161856074
# after 4235 loops, the current loss is 54.13338136925327
# after 4239 loops, the current loss is 54.12507111994581
# after 4243 loops, the current loss is 54.1167608706383
# after 4247 loops, the current loss is 54.10845062133084
# after 4251 loops, the current loss is 54.100140372023375
# after 4255 loops, the current loss is 54.09183012271587
# after 4259 loops, the current loss is 54.083519873408406
# after 4263 loops, the current loss is 54.07520962410093
# after 4267 loops, the current loss is 54.06689937479345
# after 4271 loops, the current loss is 54.05858912548597
# after 4275 loops, the current loss is 54.0502788761785
# after 4279 loops, the current loss is 54.04196862687102
# after 4283 loops, the current loss is 54.033658377563526
# after 4287 loops, the current loss is 54.02534812825607
# after 4291 loops, the current loss is 54.01703787894858
# after 4295 loops, the current loss is 54.00872762964109
# after 4299 loops, the current loss is 54.00041738033364
# after 4303 loops, the current loss is 53.992107131026145
# after 4307 loops, the current loss is 53.98379688171866
# after 4311 loops, the current loss is 53.97548663241119
# after 4315 loops, the current loss is 53.96717638310371
# after 4319 loops, the current loss is 53.95886613379622
# after 4323 loops, the current loss is 53.95055588448874
# after 4327 loops, the current loss is 53.942245635181266
# after 4331 loops, the current loss is 53.93393538587379
# after 4335 loops, the current loss is 53.9256251365663
# after 4341 loops, the current loss is 53.89626225567989
# after 4347 loops, the current loss is 53.87880633788567
# after 4351 loops, the current loss is 53.87603625478318
# after 4355 loops, the current loss is 53.87326617168068
# after 4359 loops, the current loss is 53.870496088578214
# after 4363 loops, the current loss is 53.867726005475696
# after 4367 loops, the current loss is 53.86495592237321
# after 4371 loops, the current loss is 53.862185839270715
# after 4375 loops, the current loss is 53.85941575616823
# after 4379 loops, the current loss is 53.856645673065735
# after 4383 loops, the current loss is 53.85387558996324
# after 4387 loops, the current loss is 53.85110550686075
# after 4391 loops, the current loss is 53.84833542375826
# after 4395 loops, the current loss is 53.84556534065575
# after 4399 loops, the current loss is 53.84279525755328
# after 4403 loops, the current loss is 53.84002517445078
# after 4407 loops, the current loss is 53.83725509134828
# after 4411 loops, the current loss is 53.834485008245814
# after 4415 loops, the current loss is 53.8317149251433
# after 4419 loops, the current loss is 53.828944842040805
# after 4423 loops, the current loss is 53.82617475893833
# after 4427 loops, the current loss is 53.82340467583581
# after 4431 loops, the current loss is 53.820634592733335
# after 4435 loops, the current loss is 53.81786450963084
# after 4439 loops, the current loss is 53.815094426528354
# after 4443 loops, the current loss is 53.81232434342586
# after 4447 loops, the current loss is 53.80955426032336
# after 4451 loops, the current loss is 53.80678417722087
# after 4455 loops, the current loss is 53.80401409411838
# after 4459 loops, the current loss is 53.801244011015875
# after 4463 loops, the current loss is 53.7984739279134
# after 4467 loops, the current loss is 53.7957038448109
# after 4471 loops, the current loss is 53.792933761708404
# after 4475 loops, the current loss is 53.79016367860593
# after 4479 loops, the current loss is 53.787393595503424
# after 4483 loops, the current loss is 53.78462351240093
# after 4487 loops, the current loss is 53.78185342929845
# after 4491 loops, the current loss is 53.77908334619593
# after 4495 loops, the current loss is 53.77631326309345
# after 4499 loops, the current loss is 53.77354317999096
# after 4503 loops, the current loss is 53.770773096888476
# after 4507 loops, the current loss is 53.76800301378598
# after 4511 loops, the current loss is 53.76523293068348
# after 4515 loops, the current loss is 53.76246284758099
# after 4519 loops, the current loss is 53.7596927644785
# after 4523 loops, the current loss is 53.756922681376
# after 4527 loops, the current loss is 53.75415259827352
# after 4531 loops, the current loss is 53.751382515171024
# after 4535 loops, the current loss is 53.748612432068526
# after 4539 loops, the current loss is 53.74584234896605
# after 4543 loops, the current loss is 53.743072265863546
# after 4546 loops, the current loss is 53.737536493907136
# after 4550 loops, the current loss is 53.729226244599666
# after 4554 loops, the current loss is 53.720915995292174
# after 4558 loops, the current loss is 53.71260574598472
# after 4562 loops, the current loss is 53.704295496677226
# after 4566 loops, the current loss is 53.695985247369734
# after 4570 loops, the current loss is 53.68767499806228
# after 4574 loops, the current loss is 53.679364748754786
# after 4578 loops, the current loss is 53.671054499447315
# after 4582 loops, the current loss is 53.662744250139845
# after 4586 loops, the current loss is 53.65443400083236
# after 4590 loops, the current loss is 53.6461237515249
# after 4594 loops, the current loss is 53.6378135022174
# after 4598 loops, the current loss is 53.62950325290992
# after 4602 loops, the current loss is 53.621193003602464
# after 4606 loops, the current loss is 53.612882754294965
# after 4610 loops, the current loss is 53.6045725049875
# after 4614 loops, the current loss is 53.59626225568003
# after 4618 loops, the current loss is 53.58795200637254
# after 4622 loops, the current loss is 53.57964175706508
# after 4626 loops, the current loss is 53.57133150775759
# after 4630 loops, the current loss is 53.5630212584501
# after 4634 loops, the current loss is 53.554711009142636
# after 4638 loops, the current loss is 53.54640075983515
# after 4642 loops, the current loss is 53.538090510527674
# after 4646 loops, the current loss is 53.52978026122021
# after 4650 loops, the current loss is 53.52147001191272
# after 4654 loops, the current loss is 53.51315976260526
# after 4658 loops, the current loss is 53.504849513297756
# after 4662 loops, the current loss is 53.496539263990286
# after 4666 loops, the current loss is 53.48822901468283
# after 4670 loops, the current loss is 53.47991876537533
# after 4674 loops, the current loss is 53.47160851606787
# after 4678 loops, the current loss is 53.4632982667604
# after 4682 loops, the current loss is 53.454988017452905
# after 4686 loops, the current loss is 53.44667776814545
# after 4692 loops, the current loss is 53.41731488725901
# after 4698 loops, the current loss is 53.387952006372586
# after 4704 loops, the current loss is 53.35858912548614
# after 4710 loops, the current loss is 53.329226244599724
# after 4716 loops, the current loss is 53.299863363713314
# after 4722 loops, the current loss is 53.27050048282688
# after 4728 loops, the current loss is 53.24113760194043
# after 4734 loops, the current loss is 53.211774721054034
# after 4780 loops, the current loss is 53.209277252013194
# after 4784 loops, the current loss is 53.2065071689107
# after 4788 loops, the current loss is 53.2037370858082
# after 4792 loops, the current loss is 53.200967002705724
# after 4796 loops, the current loss is 53.19819691960322
# after 4800 loops, the current loss is 53.19542683650074
# after 4804 loops, the current loss is 53.19265675339824
# after 4808 loops, the current loss is 53.18988667029575
# after 4812 loops, the current loss is 53.187116587193245
# after 4816 loops, the current loss is 53.18434650409076
# after 4820 loops, the current loss is 53.18157642098827
# after 4824 loops, the current loss is 53.17880633788577
# after 4828 loops, the current loss is 53.17603625478328
# after 4832 loops, the current loss is 53.17326617168079
# after 4836 loops, the current loss is 53.17049608857829
# after 4840 loops, the current loss is 53.1677260054758
# after 4844 loops, the current loss is 53.164955922373316
# after 4848 loops, the current loss is 53.16218583927082
# after 4852 loops, the current loss is 53.15941575616832
# after 4856 loops, the current loss is 53.156645673065846
# after 4860 loops, the current loss is 53.15387558996334
# after 4875 loops, the current loss is 53.15221793435047
# after 4881 loops, the current loss is 53.12285505346406
# after 4887 loops, the current loss is 53.09349217257764
# after 4893 loops, the current loss is 53.06412929169121
# after 4899 loops, the current loss is 53.03476641080476
# after 4905 loops, the current loss is 53.00540352991836
# after 4911 loops, the current loss is 52.97604064903194
# after 4917 loops, the current loss is 52.94667776814551
# after 4923 loops, the current loss is 52.91731488725909
# after 4929 loops, the current loss is 52.88795200637264
# after 4943 loops, the current loss is 52.88711658719328
# after 4947 loops, the current loss is 52.88434650409081
# after 4951 loops, the current loss is 52.88157642098831
# after 4955 loops, the current loss is 52.87880633788581
# after 4959 loops, the current loss is 52.87603625478332
# after 4963 loops, the current loss is 52.87326617168085
# after 4967 loops, the current loss is 52.87283518709663
# after 5008 loops, the current loss is 52.87271654930894
# after 5014 loops, the current loss is 52.84335366842253
# after 5020 loops, the current loss is 52.81399078753611
# after 5026 loops, the current loss is 52.78462790664967
# after 5032 loops, the current loss is 52.755265025763244
# after 5038 loops, the current loss is 52.72590214487681
# after 5044 loops, the current loss is 52.696539263990395
# after 5103 loops, the current loss is 52.68906003961367
# after 5109 loops, the current loss is 52.65969715872723
# after 5115 loops, the current loss is 52.6303342778408
# after 5121 loops, the current loss is 52.600971396954385
# after 5182 loops, the current loss is 52.57243954099871
# after 5188 loops, the current loss is 52.54307666011229
# after 5194 loops, the current loss is 52.51371377922586
# after 5200 loops, the current loss is 52.51162074478019
# after 5247 loops, the current loss is 52.50180242188513
# after 5253 loops, the current loss is 52.47243954099872
# after 5259 loops, the current loss is 52.44307666011228
# after 5265 loops, the current loss is 52.42048501070817
# after 5310 loops, the current loss is 52.4184229205001
# after 5316 loops, the current loss is 52.38906003961368
# after 5322 loops, the current loss is 52.35969715872724
# after 5362 loops, the current loss is 52.33642846066632
# after 5368 loops, the current loss is 52.307065579779874
# after 5404 loops, the current loss is 52.29210713102643
# after 5410 loops, the current loss is 52.262744250139995
# after 5442 loops, the current loss is 52.25609605069402
# after 5448 loops, the current loss is 52.226733169807595
# ...
# after 6804 loops, the current loss is 50.76302125845059
# after 6811 loops, the current loss is 50.75221793435088
# after 6818 loops, the current loss is 50.74141461025115
# after 6825 loops, the current loss is 50.732950384669664
# after 6883 loops, the current loss is 50.72950325291041
# after 6890 loops, the current loss is 50.7186999288107
# after 6897 loops, the current loss is 50.70789660471098
# after 6904 loops, the current loss is 50.697093280611256
# after 6911 loops, the current loss is 50.68628995651153
# after 6918 loops, the current loss is 50.675486632411804
# after 6925 loops, the current loss is 50.66468330831209
# after 6932 loops, the current loss is 50.65387998421237
# after 6939 loops, the current loss is 50.64307666011265
# after 6946 loops, the current loss is 50.63227333601291
# after 6953 loops, the current loss is 50.62147001191318
# after 6960 loops, the current loss is 50.610666687813456
# after 6967 loops, the current loss is 50.59986336371374
# after 6974 loops, the current loss is 50.589060039614026
# after 6981 loops, the current loss is 50.57825671551431
# after 6988 loops, the current loss is 50.567453391414574
# after 6995 loops, the current loss is 50.562313265556114
# after 7065 loops, the current loss is 50.554988017453354
# after 7072 loops, the current loss is 50.544184693353614
# after 7079 loops, the current loss is 50.533381369253895
# after 7086 loops, the current loss is 50.522578045154184
# after 7093 loops, the current loss is 50.51177472105445
# after 7100 loops, the current loss is 50.50097139695474
# after 7107 loops, the current loss is 50.49016807285501
# after 7114 loops, the current loss is 50.479364748755295
# after 7121 loops, the current loss is 50.46856142465557
# after 7128 loops, the current loss is 50.457758100555836
# after 7135 loops, the current loss is 50.44695477645612
# after 7142 loops, the current loss is 50.436151452356384
# after 7149 loops, the current loss is 50.42534812825668
# after 7156 loops, the current loss is 50.41454480415695
# after 7163 loops, the current loss is 50.40374148005722
# after 7170 loops, the current loss is 50.392938155957495
# after 7177 loops, the current loss is 50.382134831857776
# after 7184 loops, the current loss is 50.37133150775804
# after 7191 loops, the current loss is 50.36175924893562
# after 7273 loops, the current loss is 50.35831211717632
# after 7280 loops, the current loss is 50.34750879307661
# after 7287 loops, the current loss is 50.33670546897688
# after 7294 loops, the current loss is 50.32590214487715
# after 7301 loops, the current loss is 50.315098820777415
# after 7308 loops, the current loss is 50.30429549667772
# after 7315 loops, the current loss is 50.29349217257798
# after 7322 loops, the current loss is 50.28268884847825
# after 7329 loops, the current loss is 50.27188552437855
# after 7336 loops, the current loss is 50.261082200278814
# after 7343 loops, the current loss is 50.25027887617909
# after 7350 loops, the current loss is 50.23947555207937
# after 7357 loops, the current loss is 50.228672227979644
# after 7364 loops, the current loss is 50.217868903879925
# after 7371 loops, the current loss is 50.20706557978018
# after 7378 loops, the current loss is 50.19626225568047
# after 7385 loops, the current loss is 50.18545893158074
# after 7392 loops, the current loss is 50.17708078048372
# after 7404 loops, the current loss is 50.17410159086052
# after 7411 loops, the current loss is 50.163298266760805
# after 7418 loops, the current loss is 50.15381208242278
# after 7430 loops, the current loss is 50.15194092604057
# after 7437 loops, the current loss is 50.14113760194087
# after 7444 loops, the current loss is 50.13054338436184
# after 7456 loops, the current loss is 50.129780261220624
# after 7463 loops, the current loss is 50.1189769371209
# after 7470 loops, the current loss is 50.108173613021165
# after 7477 loops, the current loss is 50.10367357826766
# after 7489 loops, the current loss is 50.09681627230097
# after 7496 loops, the current loss is 50.086012948201244
# after 7503 loops, the current loss is 50.08040488020672
# after 7515 loops, the current loss is 50.07465560748101
# after 7522 loops, the current loss is 50.063852283381294
# after 7529 loops, the current loss is 50.05713618214579
# after 7541 loops, the current loss is 50.052494942661056
# after 7548 loops, the current loss is 50.04169161856135
# after 7555 loops, the current loss is 50.033867484084844
# after 7567 loops, the current loss is 50.03033427784113
# after 7574 loops, the current loss is 50.0195309537414
# after 7581 loops, the current loss is 50.010598786023905
# after 7593 loops, the current loss is 50.00817361302118
# after 7600 loops, the current loss is 49.99737028892146
# after 7607 loops, the current loss is 49.98733008796295
# after 7619 loops, the current loss is 49.986012948201235
# after 7626 loops, the current loss is 49.97520962410152
# after 7633 loops, the current loss is 49.964406300001784
# after 7640 loops, the current loss is 49.96046028186878
# after 7652 loops, the current loss is 49.95304895928156
# after 7659 loops, the current loss is 49.94224563518184
# after 7666 loops, the current loss is 49.93719158380784
# after 7678 loops, the current loss is 49.930888294461624
# after 7685 loops, the current loss is 49.9200849703619
# after 7692 loops, the current loss is 49.913922885746906
# after 7704 loops, the current loss is 49.908727629641675
# after 7711 loops, the current loss is 49.897924305541956
# after 7718 loops, the current loss is 49.89065418768596
# after 7730 loops, the current loss is 49.88656696482174
# after 7737 loops, the current loss is 49.87576364072202
# after 7744 loops, the current loss is 49.86738548962502
# after 7756 loops, the current loss is 49.86440630000178
# after 7763 loops, the current loss is 49.85360297590206
# after 7770 loops, the current loss is 49.84411679156409
# after 7782 loops, the current loss is 49.842245635181825
# after 7789 loops, the current loss is 49.831442311082114
# after 7796 loops, the current loss is 49.82084809350314
# after 7808 loops, the current loss is 49.82008497036189
# after 7815 loops, the current loss is 49.80928164626217
# after 7822 loops, the current loss is 49.79847832216245
# after 7829 loops, the current loss is 49.79397828740896
# after 7841 loops, the current loss is 49.7871209814422
# after 7848 loops, the current loss is 49.7763176573425
# after 7855 loops, the current loss is 49.770709589348016
# after 7867 loops, the current loss is 49.76496031662228
# after 7874 loops, the current loss is 49.75415699252255
# after 7881 loops, the current loss is 49.74744089128708
# after 7893 loops, the current loss is 49.742799651802336
# after 7900 loops, the current loss is 49.731996327702625
# after 7907 loops, the current loss is 49.72417219322614
# after 7919 loops, the current loss is 49.72063898698239
# after 7926 loops, the current loss is 49.709835662882654
# after 7933 loops, the current loss is 49.7009034951652
# after 7945 loops, the current loss is 49.698478322162444
# after 7952 loops, the current loss is 49.687674998062725
# after 7959 loops, the current loss is 49.67763479710426
# after 7971 loops, the current loss is 49.6763176573425
# after 7978 loops, the current loss is 49.665514333242776
# after 7985 loops, the current loss is 49.65471100914304
# after 7992 loops, the current loss is 49.65076499101008
# after 8004 loops, the current loss is 49.64335366842282
# after 8011 loops, the current loss is 49.632550344323114
# after 8018 loops, the current loss is 49.62749629294914
# after 8030 loops, the current loss is 49.62119300360289
# after 8037 loops, the current loss is 49.61038967950316
# after 8044 loops, the current loss is 49.6042275948882
# after 8056 loops, the current loss is 49.59903233878293
# after 8063 loops, the current loss is 49.58822901468322
# after 8070 loops, the current loss is 49.58095889682726
# after 8082 loops, the current loss is 49.576871673962984
# after 8089 loops, the current loss is 49.56606834986327
# after 8096 loops, the current loss is 49.5576901987663
# after 8108 loops, the current loss is 49.554711009143055
# after 8115 loops, the current loss is 49.54390768504333
# after 8122 loops, the current loss is 49.534421500705385
# after 8134 loops, the current loss is 49.53255034432311
# after 8141 loops, the current loss is 49.52174702022338
# after 8148 loops, the current loss is 49.51115280264444
# after 8160 loops, the current loss is 49.51038967950316
# after 8167 loops, the current loss is 49.49958635540344
# after 8174 loops, the current loss is 49.488783031303704
# after 8181 loops, the current loss is 49.48428299655025
# after 8193 loops, the current loss is 49.47742569058348
# after 8200 loops, the current loss is 49.46662236648376
# after 8207 loops, the current loss is 49.46101429848931
# after 8219 loops, the current loss is 49.455265025763545
# after 8226 loops, the current loss is 49.44446170166383
# after 8233 loops, the current loss is 49.43774560042839
# after 8245 loops, the current loss is 49.43310436094359
# after 8252 loops, the current loss is 49.42230103684387
# after 8259 loops, the current loss is 49.414476902367454
# after 8291 loops, the current loss is 49.408382719541954
# after 8296 loops, the current loss is 49.39591734558074
# after 8301 loops, the current loss is 49.383451971619515
# after 8306 loops, the current loss is 49.3763176573425
# after 8313 loops, the current loss is 49.36738548962506
# after 8345 loops, the current loss is 49.361291306799586
# after 8350 loops, the current loss is 49.34882593283836
# after 8355 loops, the current loss is 49.336360558877146
# after 8387 loops, the current loss is 49.33026637605167
# after 8392 loops, the current loss is 49.31780100209045
# after 8397 loops, the current loss is 49.30533562812923
# after 8429 loops, the current loss is 49.29924144530375
# after 8434 loops, the current loss is 49.28677607134252
# after 8439 loops, the current loss is 49.27431069738132
# after 8444 loops, the current loss is 49.26184532342009
# after 8476 loops, the current loss is 49.255751140594604
# after 8481 loops, the current loss is 49.24328576663339
# after 8486 loops, the current loss is 49.23082039267218
# after 8489 loops, the current loss is 49.22534812825667
# after 8518 loops, the current loss is 49.224726209846686
# after 8523 loops, the current loss is 49.212260835885466
# after 8528 loops, the current loss is 49.19979546192426
# after 8531 loops, the current loss is 49.17991876537578
# after 8570 loops, the current loss is 49.16877053117635
# after 8575 loops, the current loss is 49.156305157215115
# after 8578 loops, the current loss is 49.14473870997413
# after 8612 loops, the current loss is 49.13774560042842
# after 8617 loops, the current loss is 49.125280226467204
# after 8620 loops, the current loss is 49.10395058657801
# after 8652 loops, the current loss is 49.09785640375252
# after 8655 loops, the current loss is 49.076526763863335
# after 8687 loops, the current loss is 49.070432581037856
# after 8690 loops, the current loss is 49.04910294114866
# after 8722 loops, the current loss is 49.043008758323175
# after 8725 loops, the current loss is 49.02167911843399
# after 8757 loops, the current loss is 49.0155849356085
# after 8760 loops, the current loss is 48.99425529571929
# after 8763 loops, the current loss is 48.992107131026806
# after 8792 loops, the current loss is 48.98816111289382
# after 8795 loops, the current loss is 48.96683147300463
# after 8798 loops, the current loss is 48.95748109224566
# after 8830 loops, the current loss is 48.93940765028995
# after 8833 loops, the current loss is 48.9228550534645
# after 8865 loops, the current loss is 48.91198382757527
# after 8868 loops, the current loss is 48.890654187686074
# after 8893 loops, the current loss is 48.88816111289383
# after 8896 loops, the current loss is 48.86683147300464
# after 8919 loops, the current loss is 48.85547413228442
# after 8944 loops, the current loss is 48.85298105749217
# after 8947 loops, the current loss is 48.83165141760298
# after 8972 loops, the current loss is 48.82915834281075
# after 8975 loops, the current loss is 48.80782870292154
# after 9000 loops, the current loss is 48.80533562812931
# after 9003 loops, the current loss is 48.78400598824011
# after 9028 loops, the current loss is 48.78151291344786
# after 9031 loops, the current loss is 48.760183273558674
# after 9054 loops, the current loss is 48.74882593283845
# after 9057 loops, the current loss is 48.73227333601305
# after 9082 loops, the current loss is 48.72500321815701
# after 9085 loops, the current loss is 48.70845062133161
# after 9110 loops, the current loss is 48.70118050347556
# after 9113 loops, the current loss is 48.68462790665018
# after 9138 loops, the current loss is 48.67735778879414
# after 9141 loops, the current loss is 48.66080519196874
# after 9164 loops, the current loss is 48.64467080818472
# after 9185 loops, the current loss is 48.62444920153653
# after 9201 loops, the current loss is 48.61669296884954
# after 9222 loops, the current loss is 48.596471362201356
# after 9243 loops, the current loss is 48.57624975555317
# after 9259 loops, the current loss is 48.56849352286619
# after 9280 loops, the current loss is 48.54827191621798
# after 9296 loops, the current loss is 48.54051568353101
# after 9299 loops, the current loss is 48.536151452356634
# after 9317 loops, the current loss is 48.52029407688281
# after 9333 loops, the current loss is 48.512537844195855
# after 9336 loops, the current loss is 48.499863363714
# after 9354 loops, the current loss is 48.49231623754764
# after 9357 loops, the current loss is 48.48684397313229
# after 9370 loops, the current loss is 48.48456000486067
# after 9373 loops, the current loss is 48.46357527507134
# after 9394 loops, the current loss is 48.450555884489646
# after 9410 loops, the current loss is 48.435252525636294
# after 9424 loops, the current loss is 48.42507111994672
# after 9440 loops, the current loss is 48.410875794334366
# after 9454 loops, the current loss is 48.39958635540381
# after 9470 loops, the current loss is 48.386499063032424
# after 9484 loops, the current loss is 48.3741015908609
# after 9500 loops, the current loss is 48.36212233173049
# after 9514 loops, the current loss is 48.34861682631797
# after 9530 loops, the current loss is 48.33774560042857
# after 9544 loops, the current loss is 48.32313206177507
# after 9558 loops, the current loss is 48.32091599529307
# after 9569 loops, the current loss is 48.30921374447289
# after 9583 loops, the current loss is 48.29259324585794
# after 9597 loops, the current loss is 48.28296585678896
# after 9608 loops, the current loss is 48.280681888517236
# after 9622 loops, the current loss is 48.26406138990226
# after 9636 loops, the current loss is 48.247440891287305
# after 9650 loops, the current loss is 48.24279965180284
# after 9661 loops, the current loss is 48.2355295339466
# after 9675 loops, the current loss is 48.218909035331656
# after 9689 loops, the current loss is 48.204849513298704
# after 9703 loops, the current loss is 48.20263344681672
# after 9714 loops, the current loss is 48.19037717937597
# after 9728 loops, the current loss is 48.17375668076103
# after 9742 loops, the current loss is 48.16468330831258
# after 9753 loops, the current loss is 48.16184532342031
# after 9767 loops, the current loss is 48.14522482480533
# after 9781 loops, the current loss is 48.1286043261904
# after 9795 loops, the current loss is 48.12451710332649
# after 9806 loops, the current loss is 48.11669296884967
# after 9820 loops, the current loss is 48.10007247023471
# after 9834 loops, the current loss is 48.086566964822374
# after 9848 loops, the current loss is 48.08435089834038
# after 9859 loops, the current loss is 48.07154061427905
# after 9873 loops, the current loss is 48.0549201156641
# after 9887 loops, the current loss is 48.04640075983624
# after 9898 loops, the current loss is 48.04300875832337
# after 9912 loops, the current loss is 48.02638825970843
# after 9926 loops, the current loss is 48.009767761093464
# after 9940 loops, the current loss is 48.00623455485013
# after 9951 loops, the current loss is 47.997856403752756
# after 9965 loops, the current loss is 47.981235905137794
# after 9979 loops, the current loss is 47.968284416346
# after 9993 loops, the current loss is 47.96606834986404
